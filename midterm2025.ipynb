# %% [markdown]
# <a href="https://colab.research.google.com/github/Konwalai1111/dataviz2025/blob/main/midterm2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ให้สืบหาฆาตรกร (10 คะแนน) และ ผู้บงการ (5 คะแนน) ในคดี ฆาตรกรรม (murder) ที่เกิดขึ้นในวันที่ 15 มกราคม 2018 ที่เมือง Pandas City โดยเริ่มจากการตรวจสอบ ข้อมูลคดีในไฟล์ crime_scene_report.csv

# %% [markdown]
# #Import libary&Google Drive

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #crime scene

# %%
crime_scene_df = pd.read_csv('/content/drive/MyDrive/Exam_Data_DataViz2025/data/crime_scene_report.csv')
crime_scene_df
# Out:
#           date     type                                        description  \
# 0     20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1     20180115   murder                  Life? Dont talk to me about life.
# 2     20180115   murder  Mama, I killed a man, put a gun against his he...
# 3     20180215   murder                         REDACTED REDACTED REDACTED
# 4     20180215   murder  Someone killed the guard! He took an arrow to ...
# ...        ...      ...                                                ...
# 1223  20180430  bribery                                                 \n
# 1224  20180430    fraud                  ‘Why not?’ said the March Hare.\n
# 1225  20180430  assault                                                 \n
# 1226  20180501  assault  be NO mistake about it: it was neither more no...
# 1227  20180115   murder  Security footage shows that there were 2 witne...
#
#               city
# 0              NYC
# 1           Albany
# ...

# %%
crime_scene_df[['date','type','city']]
# Out:
#           date     type          city
# 0     20180115  robbery           NYC
# 1     20180115   murder        Albany
# 2     20180115   murder          Reno
# 3     20180215   murder   Pandas City
# 4     20180215   murder   Pandas City
# ...        ...      ...           ...
# 1223  20180430  bribery  Garden Grove
# 1224  20180430    fraud         Houma
# 1225  20180430  assault       Fontana
# 1226  20180501  assault       Trenton
# 1227  20180115   murder   Pandas City
#
# [1228 rows x 3 columns]

# %%
murder_case_df = crime_scene_df[
    (crime_scene_df['date'] == 20180115) &
    (crime_scene_df['type'] == 'murder') &
    (crime_scene_df['city'] == 'Pandas City')
]
murder_case_df
# Out:
#           date    type                                        description  \
# 1227  20180115  murder  Security footage shows that there were 2 witne...
#
#              city
# 1227  Pandas City

# %% [markdown]
# #witness

# %%
person_df = pd.read_csv('/content/drive/MyDrive/Exam_Data_DataViz2025/data/person.csv')
person_df
# Out:
#           id                 name  license_id  address_number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
# ...      ...                  ...         ...             ...
# 10006  99936          Luba Benser      274427             680
# 10007  99941      Roxana Mckimley      975942            1613
# 10008  99965      Cherie Zeimantz      287627            3661
# 10009  99982          Allen Cruse      251350            3126
# 10010  99990         Vance Hunten      830407            3056
#
#       address_street_name        ssn
# 0            Bankhall Ave  747714076
# 1           Gustavus Blvd  477972044
# 2         Northwestern Dr  828638512
# 3           Wood Glade St  614621061
# ...

# %%
witness_df = person_df[
    (person_df['name'] == 'Annabel Miller') |
    (person_df['name'] == 'Morty Schapiro')
]
witness_df
# Out:
#         id            name  license_id  address_number address_street_name  \
# 499  14887  Morty Schapiro      118009            4919     Northwestern Dr
# 665  16371  Annabel Miller      490173             103        Franklin Ave
#
#            ssn
# 499  111564949
# 665  318771143

# %%
interview_df = pd.read_csv('/content/drive/MyDrive/Exam_Data_DataViz2025/data/interview.csv')
interview_df
# Out:
#       person_id                                         transcript
# 0         28508                ‘I deny it!’ said the March Hare.\n
# 1         63713                                                 \n
# 2         86208      way, and the whole party swam to the shore.\n
# 3         35267  lessons in here? Why, there’s hardly room for ...
# 4         33856                                                 \n
# ...         ...                                                ...
# 4986      37357  Alice did not wish to offend the Dormouse agai...
# 4987      10206  time,’ she said, ‘than waste it in asking ridd...
# 4988      14887  I heard a gunshot and then saw a man run out. ...
# 4989      16371  I saw the murder happen, and I recognized the ...
# 4990      67318  I was hired by a woman with a lot of money. I ...
#
# [4991 rows x 2 columns]

# %%
transcript_df = interview_df[
    (interview_df['person_id'] == witness_df.iloc[0]['id']) |
    (interview_df['person_id'] == witness_df.iloc[1]['id'])
]
display(transcript_df)
# Out:
#       person_id                                         transcript
# 4988      14887  I heard a gunshot and then saw a man run out. ...
# 4989      16371  I saw the murder happen, and I recognized the ...

# %% [markdown]
# #murder

# %%
drivers_license_df = pd.read_csv('/content/drive/MyDrive/Exam_Data_DataViz2025/data/drivers_license.csv')
drivers_license_df
# Out:
#            id  age  height eye_color hair_color  gender plate_number  \
# 0      100280   72      57     brown        red    male       P24L4U
# 1      100460   63      72     brown      brown  female       XF02T6
# 2      101029   62      74     green      green  female       VKY5KR
# 3      101198   43      54     amber      brown  female       Y5NZ08
# 4      101255   18      79      blue       grey  female       5162Z1
# ...       ...  ...     ...       ...        ...     ...          ...
# 10002  999923   19      77     amber      black  female       5L0ZI4
# 10003  999940   71      61     green      green    male       1B8QN8
# 10004  999981   67      69     brown       blue  female       1684K3
# 10005  999986   49      58     green       grey    male       F8F64H
# 10006  999993   18      63     black      black  female       6UZO2O
#
#          car_make    car_model
# 0           Acura          MDX
# 1        Cadillac          SRX
# 2           Scion           xB
# ...

# %%
search_plate_number = "H42W"
result = drivers_license_df[drivers_license_df['plate_number'].str.contains(search_plate_number, case=False, na=False)]
print(result)
# Out:
#           id  age  height eye_color hair_color  gender plate_number  \
# 915   183779   21      65      blue     blonde  female       H42W0X
# 3529  423327   30      70     brown      brown    male       0H42W2
# 6240  664760   21      71     black      black    male       4H42WR
#
#        car_make car_model
# 915      Toyota     Prius
# 3529  Chevrolet  Spark LS
# 6240     Nissan    Altima

# %%
search_car_make = "Tesla"
search_car_model = "Model S"

result = drivers_license_df[
    drivers_license_df['car_make'].str.contains(search_car_make, case=False, na=False) &
    drivers_license_df['car_model'].str.contains(search_car_model, case=False, na=False)
]

print(result)
# Out:
#           id  age  height eye_color hair_color  gender plate_number car_make  \
# 1105  202298   68      66     green        red  female       500123    Tesla
# 2054  291182   65      66      blue        red  female       08CM64    Tesla
# 4012  467669   70      65     green      white    male       W528W7    Tesla
# 5975  638311   72      63     amber      white    male       0M846T    Tesla
# 6428  682231   51      80     green       grey  female       3Z0M62    Tesla
# 7083  736081   79      69     brown        red    male       GCAQ6Y    Tesla
# 9078  918773   48      65     black        red  female       917UU3    Tesla
#
#      car_model
# 1105   Model S
# 2054   Model S
# 4012   Model S
# 5975   Model S
# 6428   Model S
# 7083   Model S
# 9078   Model S

# %%
Gym_member_df = pd.read_csv('/content/drive/MyDrive/Exam_Data_DataViz2025/data/get_fit_now_member.csv')
Gym_member_df
# Out:
#         id  person_id                name  membership_start_date  \
# 0    NL318      65076     Everette Koepke               20170926
# 1    AOE21      39426        Noe Locascio               20171005
# 2    2PN28      63823  Jeromy Heitschmidt               20180215
# 3    0YJ24      80651      Waneta Wellard               20171206
# 4    3A08L      32858        Mei Bianchin               20170401
# ..     ...        ...                 ...                    ...
# 179  2V137      41693      Wendell Dulany               20171219
# 180  4KB72      79110          Emile Hege               20170522
# 181  48Z7A      28819        Joe Germuska               20160305
# 182  48Z55      67318       Jeremy Bowers               20160101
# 183  90081      16371      Annabel Miller               20160208
#
#     membership_status
# 0                gold
# 1             regular
# 2              silver
# 3                gold
# 4              silver
# ..                ...
# ...

# %%
gold_member_df = Gym_member_df[
    (Gym_member_df['membership_status'] == 'gold')]
display(gold_member_df)
# Out:
#         id  person_id               name  membership_start_date  \
# 0    NL318      65076    Everette Koepke               20170926
# 3    0YJ24      80651     Waneta Wellard               20171206
# 6    5Y28Y      15218  Millicent Yessios               20180205
# 8    A5N3S      24541       Mary Cameron               20170501
# 12   R4J4S      13703         Lien Yasin               20170414
# ..     ...        ...                ...                    ...
# 166  0T622      98782    Sarina Overpeck               20171109
# 170  BL3KC      24033      Collene Gulde               20170913
# 181  48Z7A      28819       Joe Germuska               20160305
# 182  48Z55      67318      Jeremy Bowers               20160101
# 183  90081      16371     Annabel Miller               20160208
#
#     membership_status
# 0                gold
# 3                gold
# 6                gold
# 8                gold
# 12               gold
# ..                ...
# 166              gold
# ...

# %%
search_gold_member = "48Z"
result = Gym_member_df[Gym_member_df['id'].str.contains(search_gold_member, case=False, na=False)]
print(result)
# Out:
#         id  person_id           name  membership_start_date membership_status
# 154  48Z38      49550  Tomas Baisley               20170203            silver
# 181  48Z7A      28819   Joe Germuska               20160305              gold
# 182  48Z55      67318  Jeremy Bowers               20160101              gold

# %%
check_in_df = pd.read_csv('/content/drive/MyDrive/Exam_Data_DataViz2025/data/get_fit_now_check_in.csv')
check_in_df
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 0            NL318       20180212            329             365
# 1            NL318       20170811            469             920
# 2            NL318       20180429            506             554
# 3            NL318       20180128            124             759
# 4            NL318       20171027            418            1019
# ...            ...            ...            ...             ...
# 2698         4KB72       20170422           1016            1114
# 2699         4KB72       20170630            408             885
# 2700         48Z7A       20180109           1600            1730
# 2701         48Z55       20180109           1530            1700
# 2702         90081       20180109           1600            1700
#
# [2703 rows x 4 columns]

# %%
search_CheckIn = "20180109"
result = check_in_df[check_in_df['check_in_date']. astype(str).str.contains(search_CheckIn, case=False, na=False)]
print(result)
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 113          X0643       20180109            957            1164
# 889          UK1F2       20180109            344             518
# 1329         XTE42       20180109            486            1124
# 1446         1AE2H       20180109            461             944
# 1703         6LSTG       20180109            399             515
# 2137         7MWHJ       20180109            273             885
# 2435         GE5Q8       20180109            367             959
# 2700         48Z7A       20180109           1600            1730
# 2701         48Z55       20180109           1530            1700
# 2702         90081       20180109           1600            1700

# %%
facebook_event_df = pd.read_csv('/content/drive/MyDrive/Exam_Data_DataViz2025/data/facebook_event_checkin.csv')
facebook_event_df
# Out:
#        person_id  event_id                                         event_name  \
# 0          28508      5880    Nudists are people who wear one-button suits.\n
# 1          63713      3865  but that's because it's the best book on anyth...
# 2          63713      3999           If Murphy's Law can go wrong, it will.\n
# 3          63713      6436  Old programmers never die.  They just branch t...
# 4          82998      4470               Help a swallow land at Capistrano.\n
# ...          ...       ...                                                ...
# 20006      99716      1143                               SQL Symphony Concert
# 20007      99716      1143                               SQL Symphony Concert
# 20008      99716      1143                               SQL Symphony Concert
# 20009      67318      4719                             The Funky Grooves Tour
# 20010      67318      1143                               SQL Symphony Concert
#
#            date
# ...

# %%
search_event = "67318"
result = facebook_event_df[facebook_event_df['person_id']. astype(str).str.contains(search_event, case=False, na=False)]
print(result)
# Out:
#        person_id  event_id              event_name      date
# 20009      67318      4719  The Funky Grooves Tour  20180115
# 20010      67318      1143    SQL Symphony Concert  20171206

# %%
search_event = "67318"
result = interview_df[interview_df['person_id']. astype(str).str.contains(search_event, case=False, na=False)]
display(result)
# Out:
#       person_id                                         transcript
# 4990      67318  I was hired by a woman with a lot of money. I ...

# %%
search_event = "The Funky Grooves Tour"
result = facebook_event_df[facebook_event_df['event_name']. astype(str).str.contains(search_event, case=False, na=False)]
print(result)
# Out:
#        person_id  event_id              event_name      date
# 20004      14887      4719  The Funky Grooves Tour  20180115
# 20005      16371      4719  The Funky Grooves Tour  20180115
# 20009      67318      4719  The Funky Grooves Tour  20180115

# %%
search_event = "SQL Symphony Concert"
result = facebook_event_df[facebook_event_df['event_name']. astype(str).str.contains(search_event, case=False, na=False)]
print(result)
# Out:
#        person_id  event_id            event_name      date
# 11         97207      1143  SQL Symphony Concert  20170322
# 12         97207      1143  SQL Symphony Concert  20180226
# 109        92433      1143  SQL Symphony Concert  20170821
# 110        92433      1143  SQL Symphony Concert  20180327
# 296        88952      1143  SQL Symphony Concert  20170918
# ...          ...       ...                   ...       ...
# 20003      24556      1143  SQL Symphony Concert  20171224
# 20006      99716      1143  SQL Symphony Concert  20171206
# 20007      99716      1143  SQL Symphony Concert  20171212
# 20008      99716      1143  SQL Symphony Concert  20171229
# 20010      67318      1143  SQL Symphony Concert  20171206
#
# [212 rows x 4 columns]

# %%
search_murder = "918773"
result = person_df[person_df['id']. astype(str).str.contains(search_murder, case=False, na=False)]
print(result)
# Out:
# Empty DataFrame
# Columns: [id, name, license_id, address_number, address_street_name, ssn]
# Index: []

# %%
search_murder = "67318"
result = person_df[person_df['id']. astype(str).str.contains(search_murder, case=False, na=False)]
print(result)
# Out:
#          id           name  license_id  address_number    address_street_name  \
# 6327  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#             ssn
# 6327  871539279

# %%
income_df = pd.read_csv('/content/drive/MyDrive/Exam_Data_DataViz2025/data/income.csv')
income_df
# Out:
#             ssn  annual_income
# 0     100009868          52200
# 1     100169584          64500
# 2     100300433          74400
# 3     100355733          35900
# 4     100366269          73000
# ...         ...            ...
# 7509  999679296          54400
# 7510  999762859          77000
# 7511  999824984          82000
# 7512  999910617          82600
# 7513  999942603          11500
#
# [7514 rows x 2 columns]

# %%
search_murder_income = "871539279"
result = income_df[income_df['ssn']. astype(str).str.contains(search_murder_income, case=False, na=False)]
print(result)
# Out:
#             ssn  annual_income
# 6474  871539279          10500

# %% [markdown]
# #Answer

# %% [markdown]
# - ฆาตกรคือ
# > Jeremy Bowers
# - คนบงการคือ
# >
